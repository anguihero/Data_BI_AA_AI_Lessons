# %% [markdown]
# # Prueba de Conocimiento en Análisis de Datos
#
# Este notebook está diseñado para evaluar conocimientos en:
# 1. Lectura de datos desde Excel
# 2. Análisis exploratorio de datos
# 3. Tratamiento de valores ausentes
# 4. Transformaciones de variables
# 5. Análisis de correlación
# 6. Visualización de datos
#
# ## Importación de librerías necesarias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de visualización
plt.style.use('seaborn')
sns.set_palette('husl')
# %matplotlib inline

# %% [markdown]
# ## 1. Lectura de Datos
#
# Debes leer un archivo Excel y seleccionar la primera hoja. Usa pandas read_excel()

# %%
## Aquí debes escribir el código para leer el archivo Excel
# Ejemplo: df = pd.read_excel('tu_archivo.xlsx', sheet_name=0)

# Mostrar las primeras filas y la información del DataFrame
print("Primeras 5 filas:")
## Aquí debes mostrar las primeras filas

print("\nInformación del DataFrame:")
## Aquí debes mostrar la información del DataFrame

# %% [markdown]
# ## 2. Análisis Descriptivo
#
# Realiza al menos 5 preguntas analíticas sobre los datos:

# %%
# 1. ¿Cuál es el resumen estadístico de las variables numéricas?
## Aquí debes usar df.describe()

# 2. ¿Cuál es la distribución de frecuencias de las variables categóricas?
## Aquí debes usar value_counts() para variables categóricas

# 3. ¿Cuáles son las medidas de tendencia central por categoría?
## Aquí debes usar groupby() y agg()

# 4. ¿Cuál es la distribución de los datos numéricos?
## Aquí debes crear histogramas

# 5. ¿Existen valores atípicos en las variables numéricas?
## Aquí debes crear boxplots

# %% [markdown]
# ## 3. Detección y Tratamiento de Valores Ausentes
#
# Analiza y trata los valores faltantes en el dataset

# %%
# Detectar valores ausentes
## Aquí debes usar df.isnull().sum()

# Visualizar el patrón de valores ausentes
## Aquí debes crear un heatmap de valores ausentes

# Tratar valores ausentes
## Aquí debes implementar estrategias de imputación

# %% [markdown]
# ## 4. Transformaciones de Variables
#
# Realiza transformaciones de variables numéricas a categóricas y viceversa

# %%
# Transformar variable numérica a categórica
## Aquí debes usar pd.cut() o pd.qcut()

# Codificar variable categórica
## Aquí debes usar pd.get_dummies() o LabelEncoder

# %% [markdown]
# ## 5. Análisis de Correlación
#
# Analiza las relaciones entre variables numéricas

# %%
# Calcular matriz de correlación
## Aquí debes usar df.corr()

# Visualizar correlaciones
plt.figure(figsize=(10, 8))
## Aquí debes crear un heatmap de correlaciones

# %% [markdown]
# ## 6. Diagramas de Caja
#
# Analiza la distribución y valores atípicos por grupos

# %%
# Crear diagramas de caja para variables numéricas por categoría
plt.figure(figsize=(12, 6))
## Aquí debes usar sns.boxplot()

# %% [markdown]
# ## 7. Exportar datos

# %%
# Exportar el DataFrame transformado a un archivo Excel
# df.to_excel('resultados_transformados.xlsx', index=False)

print("Los resultados transformados se han exportado exitosamente a 'resultados_transformados.xlsx'.")
