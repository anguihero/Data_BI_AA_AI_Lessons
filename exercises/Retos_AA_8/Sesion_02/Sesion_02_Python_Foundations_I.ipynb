# %% [markdown]
# ---
#
# # Sesión 02: Python Foundations I (Junior)
# ## 6 Problemas Clásicos de Python
#
# **Objetivo**: Dominar las estructuras de datos y control de flujo fundamentales de Python.
# ---

# %% [markdown]
# ---
#
# ## 📚 Sobre este Material
#
# Este material ha sido diseñado con el propósito de capacitar, actualizar y fortalecer las competencias en el manejo de datos con Python.
#
# ### 🤝 Compartir y Colaborar
#
# Este contenido es **libre para compartir, revisar, divulgar y mejorar**. Se promueve activamente su distribución en la comunidad para que más personas puedan beneficiarse y contribuir a su mejora continua. Tu feedback y sugerencias son siempre bienvenidos.
#
# ### 👨‍💻 Autor
#
# **Andrés Muñoz**
# *AI & Data Strategy Leader passionate about NLP, LLMs, and MLOps. Driving innovation with data*
#
# - 💼 LinkedIn: [in/amms1989](https://linkedin.com/in/amms1989)
# - 🐙 GitHub: [https://github.com/anguihero](https://github.com/anguihero)
#
# ---

# %% [markdown]
# ## Problema 1: Manipulación de Listas
#
# **Desafío**: Crea una función que reciba una lista de números y retorne una nueva lista con:
# - Los números pares duplicados (multiplicados por 2)
# - Los números impares triplicados (multiplicados por 3)
#
# **Ejemplo**:
# ```python
# Input: [1, 2, 3, 4, 5]
# Output: [3, 4, 9, 8, 15]
# ```

# %%
def transformar_lista(numeros):
    """
    Transforma una lista multiplicando pares x2 e impares x3.
    
    Args:
        numeros (list): Lista de números enteros
    
    Returns:
        list: Lista transformada
    """
    # TODO: Implementa tu solución aquí
    pass

# Casos de prueba
print("Test 1:", transformar_lista([1, 2, 3, 4, 5]))  # Esperado: [3, 4, 9, 8, 15]
print("Test 2:", transformar_lista([10, 15, 20]))     # Esperado: [20, 45, 40]
print("Test 3:", transformar_lista([]))               # Esperado: []

# %% [markdown]
# ## Problema 2: Diccionarios Avanzados
#
# **Desafío**: Dada una lista de estudiantes (cada uno es un diccionario con nombre y lista de calificaciones), retorna un nuevo diccionario con el nombre del estudiante y su promedio.
#
# **Ejemplo**:
# ```python
# estudiantes = [
#     {"nombre": "Ana", "calificaciones": [85, 90, 78]},
#     {"nombre": "Carlos", "calificaciones": [92, 88, 95]}
# ]
# # Resultado: {"Ana": 84.33, "Carlos": 91.67}
# ```

# %%
def calcular_promedios(estudiantes):
    """
    Calcula el promedio de calificaciones de cada estudiante.
    
    Args:
        estudiantes (list): Lista de diccionarios con nombre y calificaciones
    
    Returns:
        dict: Diccionario con nombre y promedio de cada estudiante
    """
    # TODO: Implementa tu solución aquí
    pass

# Casos de prueba
estudiantes = [
    {"nombre": "Ana", "calificaciones": [85, 90, 78]},
    {"nombre": "Carlos", "calificaciones": [92, 88, 95]},
    {"nombre": "María", "calificaciones": [100, 100, 100]}
]

print("Promedios:", calcular_promedios(estudiantes))

# %% [markdown]
# ## Problema 3: Control de Flujo - FizzBuzz Mejorado
#
# **Desafío**: Implementa una versión mejorada de FizzBuzz para números del 1 al 100:
# - Divisible por 3: imprime "Fizz"
# - Divisible por 5: imprime "Buzz"
# - Divisible por ambos: imprime "FizzBuzz"
# - Si es primo: imprime "Primo"
# - De lo contrario: imprime el número

# %%
def es_primo(n):
    """
    Verifica si un número es primo.
    
    Args:
        n (int): Número a verificar
    
    Returns:
        bool: True si es primo, False en caso contrario
    """
    # TODO: Implementa la verificación de número primo
    pass

def fizzbuzz_mejorado(limite=100):
    """
    Implementa FizzBuzz mejorado con detección de primos.
    
    Args:
        limite (int): Número hasta el cual ejecutar FizzBuzz
    """
    # TODO: Implementa tu solución aquí
    pass

# Ejecutar FizzBuzz mejorado
print("FizzBuzz Mejorado (primeros 30 números):")
fizzbuzz_mejorado(30)

# %% [markdown]
# ## Problema 4: Funciones con Múltiples Parámetros
#
# **Desafío**: Crea una función que calcule estadísticas descriptivas (media, mediana, desviación estándar) sin usar librerías externas.

# %%
def estadisticas_descriptivas(numeros):
    """
    Calcula estadísticas descriptivas básicas de una lista de números.
    
    Args:
        numeros (list): Lista de números
    
    Returns:
        dict: Diccionario con media, mediana y desviación estándar
    """
    if not numeros:
        return {"media": None, "mediana": None, "desv_std": None}
    
    # TODO: Calcula la media
    media = None  # Tu código aquí
    
    # TODO: Calcula la mediana
    # Pista: Ordena la lista y toma el valor central
    mediana = None  # Tu código aquí
    
    # TODO: Calcula la desviación estándar
    # Fórmula: sqrt(sum((x - media)^2) / n)
    desv_std = None  # Tu código aquí
    
    return {
        "media": media,
        "mediana": mediana,
        "desv_std": desv_std
    }

# Casos de prueba
datos1 = [1, 2, 3, 4, 5]
datos2 = [10, 20, 30, 40, 50, 60]
datos3 = [5]

print("Datos 1:", estadisticas_descriptivas(datos1))
print("Datos 2:", estadisticas_descriptivas(datos2))
print("Datos 3:", estadisticas_descriptivas(datos3))

# %% [markdown]
# ## Problema 5: Manejo de Errores Robusto
#
# **Desafío**: Crea una función que solicite al usuario un número entero y maneje todos los posibles errores. La función debe seguir pidiendo hasta que reciba un valor válido.

# %%
def solicitar_numero_entero():
    """
    Solicita al usuario un número entero, manejando errores hasta recibir uno válido.
    
    Returns:
        int: Número entero válido ingresado por el usuario
    """
    # TODO: Implementa tu solución aquí
    # Pista: Usa un bucle while True con try/except
    # Captura ValueError para entradas no numéricas
    pass

# Versión para testing (sin input real)
def validar_numero_entero(entrada):
    """
    Valida si una entrada puede convertirse a entero.
    
    Args:
        entrada (str): Entrada a validar
    
    Returns:
        tuple: (bool, int/str) - (es_valido, valor_o_error)
    """
    # TODO: Implementa la validación
    pass

# Casos de prueba
print("Test 1:", validar_numero_entero("42"))      # (True, 42)
print("Test 2:", validar_numero_entero("abc"))     # (False, error)
print("Test 3:", validar_numero_entero("3.14"))    # (False, error)
print("Test 4:", validar_numero_entero("-10"))     # (True, -10)

# %% [markdown]
# ## Problema 6: Comprensión de Listas Avanzada
#
# **Desafío**: Dada una lista de strings, crea una nueva lista que contenga solo las palabras con más de 5 caracteres, convertidas a mayúsculas y ordenadas alfabéticamente.
#
# **Ejemplo**:
# ```python
# Input: ["python", "es", "genial", "para", "datos"]
# Output: ["GENIAL", "PYTHON"]
# ```

# %%
def filtrar_y_transformar_palabras(palabras):
    """
    Filtra palabras con más de 5 caracteres, las convierte a mayúsculas y ordena.
    
    Args:
        palabras (list): Lista de strings
    
    Returns:
        list: Lista filtrada, transformada y ordenada
    """
    # TODO: Implementa usando list comprehension
    # Pista: [expresion for item in lista if condicion]
    pass

# Casos de prueba
test1 = ["python", "es", "genial", "para", "datos"]
test2 = ["machine", "learning", "ai", "model"]
test3 = ["a", "ab", "abc", "abcd", "abcde", "abcdef"]

print("Test 1:", filtrar_y_transformar_palabras(test1))
print("Test 2:", filtrar_y_transformar_palabras(test2))
print("Test 3:", filtrar_y_transformar_palabras(test3))

# %% [markdown]
# ## 🎯 Ejercicio Bonus: Combina Todo
#
# Crea una función que reciba una lista de diccionarios (cada uno representa una transacción con 'monto', 'categoria', 'fecha') y retorne:
# 1. El total gastado por categoría
# 2. La categoría con mayor gasto
# 3. El promedio de gasto por transacción
#
# Este ejercicio combina todo lo aprendido: listas, diccionarios, funciones y lógica de control.

# %%
def analizar_transacciones(transacciones):
    """
    Analiza una lista de transacciones y genera un reporte.
    
    Args:
        transacciones (list): Lista de dict con 'monto', 'categoria', 'fecha'
    
    Returns:
        dict: Reporte con totales por categoría, mayor gasto y promedio
    """
    # TODO: Implementa tu solución aquí
    pass

# Caso de prueba
transacciones = [
    {"monto": 50.00, "categoria": "Comida", "fecha": "2023-01-15"},
    {"monto": 120.00, "categoria": "Transporte", "fecha": "2023-01-16"},
    {"monto": 80.00, "categoria": "Comida", "fecha": "2023-01-17"},
    {"monto": 200.00, "categoria": "Entretenimiento", "fecha": "2023-01-18"},
    {"monto": 45.00, "categoria": "Transporte", "fecha": "2023-01-19"}
]

print("Análisis de transacciones:")
print(analizar_transacciones(transacciones))

# %% [markdown]
# ## 🎓 Reflexión Final
#
# **Responde las siguientes preguntas**:
#
# 1. ¿Cuál de los 6 problemas encontraste más desafiante? ¿Por qué?
#
# 2. ¿Qué concepto de Python te quedó más claro después de esta sesión?
#
# 3. ¿En qué situaciones de Data Science aplicarías comprensiones de listas?
#
# 4. ¿Por qué es importante el manejo de errores en análisis de datos?
#
# ---
# **¡Felicidades!** Has completado los fundamentos básicos de Python. Estos conceptos son la base de todo tu trabajo futuro en Data Science. 🐍🚀
