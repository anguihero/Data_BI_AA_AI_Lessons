# %% [markdown]
# ---
# Autor: anmmunozsa@outlook.es
# Nota: Este es material de código abierto diseñado para compartir y aprender colectivamente.
# ---
#
# # Sesión 05: Domando Pandas
# ## Reto: Análisis de Churn de Clientes
#
# **Objetivo**: Dominar groupby, pivot tables, filtros complejos y limpieza de nulos.

# %%
# Importar librerías
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

print("Librerías cargadas correctamente ✓")

# %% [markdown]
# ## Paso 1: Crear Dataset de Churn
#
# Generamos un dataset ficticio de clientes de telecomunicaciones.

# %%
# Crear dataset de churn
np.random.seed(42)
n_customers = 500

df_churn = pd.DataFrame({
    'customer_id': [f'CUST{i:04d}' for i in range(1, n_customers + 1)],
    'tenure': np.random.randint(1, 72, n_customers),
    'monthly_charges': np.random.uniform(30, 120, n_customers).round(2),
    'contract_type': np.random.choice(['Month-to-month', 'One year', 'Two year'], n_customers, p=[0.5, 0.3, 0.2]),
    'payment_method': np.random.choice(['Electronic check', 'Mailed check', 'Bank transfer', 'Credit card'], n_customers),
    'internet_service': np.random.choice(['DSL', 'Fiber optic', 'No'], n_customers, p=[0.4, 0.4, 0.2]),
    'churn': np.random.choice(['Yes', 'No'], n_customers, p=[0.27, 0.73])
})

# Calcular total_charges (algunas entradas con valores nulos)
df_churn['total_charges'] = (df_churn['monthly_charges'] * df_churn['tenure']).round(2)
df_churn.loc[np.random.choice(df_churn.index, 15, replace=False), 'total_charges'] = np.nan

# Introducir algunos customer_id nulos (error de datos)
df_churn.loc[np.random.choice(df_churn.index, 5, replace=False), 'customer_id'] = np.nan

print("Dataset de Churn creado:")
print(f"Forma: {df_churn.shape}")
print("\nPrimeras filas:")
print(df_churn.head(10))

# %% [markdown]
# ## Paso 2: Inspección Inicial

# %%
# TODO: Realiza una inspección completa del dataset
# 1. Info general
# 2. Estadísticas descriptivas
# 3. Valores nulos por columna
# 4. Valores únicos por columna categórica

print("📊 INFORMACIÓN GENERAL")
# Tu código aquí

print("\n📊 ESTADÍSTICAS DESCRIPTIVAS")
# Tu código aquí

print("\n📊 VALORES NULOS")
# Tu código aquí

print("\n📊 VALORES ÚNICOS EN COLUMNAS CATEGÓRICAS")
# Tu código aquí

# %% [markdown]
# ## Tarea 1: GroupBy - Análisis por Segmentos
#
# Usa groupby para analizar diferentes segmentos de clientes.

# %% [markdown]
# ### 1.1: Tasa de Churn por Tipo de Contrato

# %%
# TODO: Calcula la tasa de churn (%) por tipo de contrato
# Pista: Cuenta cuántos 'Yes' hay en cada grupo y divide por el total del grupo

churn_por_contrato = None  # Tu código aquí

print("Tasa de Churn por Tipo de Contrato:")
print(churn_por_contrato)

# %% [markdown]
# ### 1.2: Promedio de Ingresos Mensuales por Método de Pago

# %%
# TODO: Calcula el promedio de monthly_charges por payment_method
# Incluye también count, min, max y std

estadisticas_pago = None  # Tu código aquí

print("Estadísticas de Ingresos Mensuales por Método de Pago:")
print(estadisticas_pago)

# %% [markdown]
# ### 1.3: Cliente con Mayor Tenure por Tipo de Internet

# %%
# TODO: Encuentra el cliente con mayor tenure en cada tipo de internet service
# Pista: Usa groupby + idxmax() o apply()

cliente_mayor_tenure = None  # Tu código aquí

print("Cliente con Mayor Tenure por Tipo de Internet:")
print(cliente_mayor_tenure)

# %% [markdown]
# ## Tarea 2: Pivot Tables - Matrices de Agregación
#
# Crea tablas dinámicas para análisis multidimensional.

# %% [markdown]
# ### 2.1: Conteo de Churn vs Tipo de Contrato

# %%
# TODO: Crea una pivot table con:
# - Filas: churn (Yes/No)
# - Columnas: contract_type
# - Valores: conteo de clientes

pivot_churn_contrato = None  # Tu código aquí

print("Pivot Table: Churn vs Tipo de Contrato")
print(pivot_churn_contrato)

# Bonus: Agrega una columna de totales
print("\nCon totales por fila:")
# Tu código aquí

# %% [markdown]
# ### 2.2: Promedio de Monthly Charges por Internet Service y Payment Method

# %%
# TODO: Crea una pivot table con:
# - Filas: internet_service
# - Columnas: payment_method
# - Valores: promedio de monthly_charges

pivot_internet_pago = None  # Tu código aquí

print("Pivot Table: Promedio de Monthly Charges")
print(pivot_internet_pago.round(2))

# %% [markdown]
# ## Tarea 3: Filtros Complejos
#
# Aplica filtros avanzados para segmentar el dataset.

# %% [markdown]
# ### 3.1: Clientes con Tenure > 12 meses AND Monthly Charges > 70

# %%
# TODO: Filtra clientes que cumplan AMBAS condiciones
# Usa & para AND

clientes_leales_alto_gasto = None  # Tu código aquí

print(f"Clientes leales con alto gasto: {len(clientes_leales_alto_gasto)}")
print("\nPrimeras filas:")
print(clientes_leales_alto_gasto.head())

# %% [markdown]
# ### 3.2: Clientes con Contrato Month-to-month OR que Hayan Hecho Churn

# %%
# TODO: Filtra clientes que cumplan AL MENOS UNA condición
# Usa | para OR

clientes_riesgo = None  # Tu código aquí

print(f"Clientes en riesgo o que ya hicieron churn: {len(clientes_riesgo)}")
print(f"\nDistribución de churn en este segmento:")
print(clientes_riesgo['churn'].value_counts())

# %% [markdown]
# ### 3.3: Clientes DSL con Charges Mayores al Promedio

# %%
# TODO: Filtra clientes con internet service = DSL
# Y monthly_charges mayor al promedio GENERAL

promedio_general = None  # Calcula aquí
clientes_dsl_premium = None  # Tu código aquí

print(f"Promedio general de monthly charges: ${promedio_general:.2f}")
print(f"Clientes DSL con charges > promedio: {len(clientes_dsl_premium)}")
print("\nEstadísticas de este segmento:")
print(clientes_dsl_premium[['monthly_charges', 'tenure']].describe())

# %% [markdown]
# ## Tarea 4: Limpieza de Valores Nulos
#
# Identifica y maneja los valores faltantes de forma inteligente.

# %% [markdown]
# ### 4.1: Identificar Columnas con Valores Nulos

# %%
# TODO: Crea un reporte de valores nulos
# Incluye: conteo de nulos y porcentaje por columna

nulos_reporte = None  # Tu código aquí

print("Reporte de Valores Nulos:")
print(nulos_reporte)

# %% [markdown]
# ### 4.2: Imputar total_charges con Mediana por Tipo de Contrato

# %%
# TODO: Imputa los valores nulos de total_charges
# Usa la mediana de total_charges de cada tipo de contrato
# Pista: groupby + transform

df_churn_limpio = df_churn.copy()

# Tu código de imputación aquí

print("Valores nulos después de imputación:")
print(df_churn_limpio['total_charges'].isnull().sum())

print("\nComparación antes/después:")
print(f"Nulos antes: {df_churn['total_charges'].isnull().sum()}")
print(f"Nulos después: {df_churn_limpio['total_charges'].isnull().sum()}")

# %% [markdown]
# ### 4.3: Eliminar Filas donde customer_id es Nulo

# %%
# TODO: Elimina las filas donde customer_id es nulo
# (No tiene sentido tener clientes sin ID)

print(f"Filas antes de limpieza: {len(df_churn_limpio)}")

# Tu código aquí

print(f"Filas después de limpieza: {len(df_churn_limpio)}")
print(f"Filas eliminadas: {len(df_churn) - len(df_churn_limpio)}")

# %% [markdown]
# ## 🎯 Análisis Integrador: Customer Lifetime Value (CLV)
#
# Calcula el valor de por vida del cliente y analiza patrones.

# %%
# TODO: Realiza un análisis completo de CLV
# 1. Calcula CLV = total_charges / tenure (gasto promedio mensual real)
# 2. Agrupa por churn y calcula estadísticas de CLV
# 3. Crea una pivot table: contract_type vs internet_service con promedio de CLV
# 4. Identifica el segmento con mayor CLV

# Paso 1: Calcular CLV
df_churn_limpio['CLV'] = None  # Tu código aquí

# Paso 2: Estadísticas por churn
print("Estadísticas de CLV por Churn:")
# Tu código aquí

# Paso 3: Pivot table
print("\nCLV Promedio por Contrato e Internet:")
# Tu código aquí

# Paso 4: Mejor segmento
print("\nSegmento con Mayor CLV:")
# Tu código aquí

# %% [markdown]
# ## 🎯 Ejercicio Bonus: Method Chaining
#
# Refactoriza un análisis completo usando method chaining.

# %%
# TODO: En UNA sola expresión encadenada, haz lo siguiente:
# 1. Filtra clientes que NO hayan hecho churn
# 2. Selecciona solo: contract_type, monthly_charges, tenure
# 3. Agrupa por contract_type
# 4. Calcula promedio de monthly_charges y tenure
# 5. Ordena por promedio de monthly_charges descendente

resultado_encadenado = (
    df_churn_limpio
    # Tu código aquí usando method chaining
)

print("Resultado con Method Chaining:")
print(resultado_encadenado)

# %% [markdown]
# ## 🎓 Reflexión Final
#
# **Responde las siguientes preguntas**:
#
# 1. ¿Qué insights de negocio descubriste sobre el churn?
#
# 2. ¿Cuándo usarías groupby vs pivot_table?
#
# 3. ¿Por qué es importante imputar valores nulos por grupo en lugar de usar un valor global?
#
# 4. ¿Qué ventaja tiene el method chaining?
#
# 5. ¿Qué tipo de contrato recomendarías promover para reducir churn?
#
# ---
# **¡Felicidades!** Has dominado Pandas a nivel avanzado. Estás listo para construir modelos de Machine Learning en la Sesión 06. 🐼🚀
