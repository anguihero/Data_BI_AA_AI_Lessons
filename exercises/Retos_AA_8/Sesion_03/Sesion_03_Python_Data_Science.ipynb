# %% [markdown]
# ---
#
#
# # Sesión 03: Python para Data Science - Lógica Matemática
#
# **Objetivo**: Dominar funciones lambda, recursividad, tipos de datos complejos y algoritmos de ordenamiento básicos.
#
# ---

# %% [markdown]
# ---
#
# ## 📚 Sobre este Material
#
# Este material ha sido diseñado con el propósito de capacitar, actualizar y fortalecer las competencias en el manejo de datos con Python.
#
# ### 🤝 Compartir y Colaborar
#
# Este contenido es **libre para compartir, revisar, divulgar y mejorar**. Se promueve activamente su distribución en la comunidad para que más personas puedan beneficiarse y contribuir a su mejora continua. Tu feedback y sugerencias son siempre bienvenidos.
#
# ### 👨‍💻 Autor
#
# **Andrés Muñoz**
# *AI & Data Strategy Leader passionate about NLP, LLMs, and MLOps. Driving innovation with data*
#
# - 💼 LinkedIn: [in/amms1989](https://linkedin.com/in/amms1989)
# - 🐙 GitHub: [https://github.com/anguihero](https://github.com/anguihero)
#
# ---

# %% [markdown]
# ## Reto 1: Funciones Lambda Avanzadas
#
# Las funciones lambda son herramientas poderosas para operaciones rápidas y concisas.

# %% [markdown]
# ### Ejercicio 1.1: Ordenar Lista de Tuplas
#
# Tienes una lista de empleados (nombre, edad, salario). Ordénala por edad en orden descendente usando lambda.

# %%
# Datos de empleados
empleados = [
    ("Ana", 28, 75000),
    ("Carlos", 35, 90000),
    ("María", 24, 65000),
    ("Juan", 42, 110000),
    ("Laura", 30, 85000)
]

# TODO: Ordena por edad descendente usando lambda y sorted()
empleados_ordenados = None  # Tu código aquí

print("Empleados ordenados por edad (descendente):")
for emp in empleados_ordenados:
    print(f"{emp[0]}: {emp[1]} años, ${emp[2]}")

# %% [markdown]
# ### Ejercicio 1.2: Filtrar Palabras que Empiezan con Vocal
#
# Usa `filter()` con lambda para extraer solo palabras que comienzan con vocal.

# %%
palabras = ["analytics", "python", "estadística", "modelo", "inteligencia", "datos", "algoritmo"]

# TODO: Filtra palabras que empiezan con vocal (a, e, i, o, u)
# Pista: usa .lower()[0] in 'aeiou'
palabras_con_vocal = None  # Tu código aquí

print("Palabras que empiezan con vocal:", list(palabras_con_vocal))

# %% [markdown]
# ### Ejercicio 1.3: Conversión de Temperaturas
#
# Usa `map()` con lambda para convertir temperaturas de Celsius a Fahrenheit.
#
# **Fórmula**: F = (C × 9/5) + 32

# %%
temperaturas_celsius = [0, 10, 20, 25, 30, 37, 100]

# TODO: Convierte a Fahrenheit usando map y lambda
temperaturas_fahrenheit = None  # Tu código aquí

print("Conversión Celsius → Fahrenheit:")
for c, f in zip(temperaturas_celsius, temperaturas_fahrenheit):
    print(f"{c}°C = {f}°F")

# %% [markdown]
# ## Reto 2: Recursividad Simple
#
# La recursividad es fundamental para entender algoritmos complejos y estructuras de datos.

# %% [markdown]
# ### Ejercicio 2.1: Cálculo de Potencia Recursiva
#
# Implementa una función recursiva que calcule base^exponente sin usar `**` o `pow()`.

# %%
def potencia_recursiva(base, exponente):
    """
    Calcula base^exponente de forma recursiva.
    
    Args:
        base (int/float): Número base
        exponente (int): Exponente (debe ser >= 0)
    
    Returns:
        int/float: Resultado de base^exponente
    """
    # TODO: Implementa tu solución recursiva
    # Pista: Caso base exponente == 0, retorna 1
    # Caso recursivo: base * potencia_recursiva(base, exponente - 1)
    pass

# Casos de prueba
print(f"2^3 = {potencia_recursiva(2, 3)}")      # Esperado: 8
print(f"5^4 = {potencia_recursiva(5, 4)}")      # Esperado: 625
print(f"10^0 = {potencia_recursiva(10, 0)}")    # Esperado: 1
print(f"3^5 = {potencia_recursiva(3, 5)}")      # Esperado: 243

# %% [markdown]
# ### Ejercicio 2.2: Inversión de String Recursiva
#
# Invierte un string usando recursividad (sin usar slicing [::-1]).

# %%
def invertir_string(texto):
    """
    Invierte un string de forma recursiva.
    
    Args:
        texto (str): String a invertir
    
    Returns:
        str: String invertido
    """
    # TODO: Implementa tu solución recursiva
    # Pista: Caso base len(texto) <= 1
    # Caso recursivo: último carácter + invertir_string(resto del string)
    pass

# Casos de prueba
print(f"'hola' invertido: {invertir_string('hola')}")           # Esperado: 'aloh'
print(f"'python' invertido: {invertir_string('python')}")       # Esperado: 'nohtyp'
print(f"'reconocer' invertido: {invertir_string('reconocer')}") # Esperado: 'reconocer'
print(f"'a' invertido: {invertir_string('a')}")                 # Esperado: 'a'

# %% [markdown]
# ### Ejercicio 2.3: Suma de Dígitos Recursiva
#
# Calcula la suma de los dígitos de un número de forma recursiva.
#
# **Ejemplo**: 123 → 1 + 2 + 3 = 6

# %%
def suma_digitos(numero):
    """
    Suma los dígitos de un número de forma recursiva.
    
    Args:
        numero (int): Número entero positivo
    
    Returns:
        int: Suma de los dígitos
    """
    # TODO: Implementa tu solución recursiva
    # Pista: Caso base numero < 10, retorna numero
    # Caso recursivo: (numero % 10) + suma_digitos(numero // 10)
    pass

# Casos de prueba
print(f"Suma dígitos de 123: {suma_digitos(123)}")    # Esperado: 6
print(f"Suma dígitos de 9875: {suma_digitos(9875)}")  # Esperado: 29
print(f"Suma dígitos de 5: {suma_digitos(5)}")        # Esperado: 5
print(f"Suma dígitos de 1000: {suma_digitos(1000)}")  # Esperado: 1

# %% [markdown]
# ## Reto 3: Manejo de Tipos de Datos Complejos
#
# Los datos del mundo real suelen estar en estructuras anidadas complejas.

# %%
# Dataset de estudiantes con estructura anidada
estudiantes = {
    "Grupo_A": [
        {"nombre": "Ana", "calificaciones": [85, 90, 88]},
        {"nombre": "Carlos", "calificaciones": [78, 82, 80]}
    ],
    "Grupo_B": [
        {"nombre": "María", "calificaciones": [95, 92, 98]},
        {"nombre": "Juan", "calificaciones": [70, 75, 73]}
    ],
    "Grupo_C": [
        {"nombre": "Laura", "calificaciones": [88, 85, 90]},
        {"nombre": "Pedro", "calificaciones": [92, 89, 91]}
    ]
}

# %% [markdown]
# ### Ejercicio 3.1: Extraer Todos los Nombres

# %%
# TODO: Extrae todos los nombres de estudiantes en una sola lista
# Pista: Usa comprensión de listas anidada o itera sobre grupos
todos_los_nombres = []  # Tu código aquí

print("Lista de todos los estudiantes:", todos_los_nombres)

# %% [markdown]
# ### Ejercicio 3.2: Calcular Promedio General

# %%
# TODO: Calcula el promedio de TODAS las calificaciones de TODOS los estudiantes
# Pista: Construye una lista plana de todas las calificaciones primero
todas_calificaciones = []  # Tu código aquí
promedio_general = None    # Calcula aquí

print(f"Promedio general de todos los estudiantes: {promedio_general:.2f}")

# %% [markdown]
# ### Ejercicio 3.3: Encontrar Mejor Estudiante

# %%
# TODO: Encuentra el estudiante con el mejor promedio individual
# Pista: Calcula el promedio de cada estudiante y guarda en un diccionario
promedios_individuales = {}  # Tu código aquí

mejor_estudiante = None      # Encuentra el mejor
mejor_promedio = None

print(f"Mejor estudiante: {mejor_estudiante} con promedio de {mejor_promedio:.2f}")
print("\nPromedios de todos los estudiantes:")
for nombre, promedio in sorted(promedios_individuales.items(), key=lambda x: x[1], reverse=True):
    print(f"  {nombre}: {promedio:.2f}")

# %% [markdown]
# ## Reto 4: Algoritmos de Ordenamiento Básico
#
# Implementar algoritmos desde cero te ayuda a entender complejidad temporal y optimización.

# %% [markdown]
# ### Ejercicio 4.1: Implementar Bubble Sort

# %%
def bubble_sort(arr):
    """
    Implementa el algoritmo Bubble Sort.
    
    Args:
        arr (list): Lista a ordenar
    
    Returns:
        tuple: (lista_ordenada, número_de_intercambios)
    """
    arr_copia = arr.copy()  # Trabajar con copia para no modificar la original
    n = len(arr_copia)
    intercambios = 0
    
    # TODO: Implementa Bubble Sort
    # Pista: Usa dos bucles for anidados
    # Compara elementos adyacentes y intercámbialos si están en orden incorrecto
    
    return arr_copia, intercambios

# Casos de prueba
test1 = [64, 34, 25, 12, 22, 11, 90]
test2 = [5, 2, 8, 1, 9]

resultado1, intercambios1 = bubble_sort(test1)
print(f"Lista original: {test1}")
print(f"Lista ordenada: {resultado1}")
print(f"Intercambios realizados: {intercambios1}\n")

resultado2, intercambios2 = bubble_sort(test2)
print(f"Lista original: {test2}")
print(f"Lista ordenada: {resultado2}")
print(f"Intercambios realizados: {intercambios2}")

# %% [markdown]
# ### Ejercicio 4.2: Comparación de Rendimiento
#
# Compara el tiempo de ejecución de tu Bubble Sort con el `sorted()` de Python.

# %%
import time
import random

# Generar lista grande de números aleatorios
lista_grande = [random.randint(1, 1000) for _ in range(1000)]

# TODO: Mide el tiempo de Bubble Sort
inicio_bubble = time.time()
# Tu código de bubble_sort aquí
fin_bubble = time.time()
tiempo_bubble = fin_bubble - inicio_bubble

# TODO: Mide el tiempo de sorted()
inicio_sorted = time.time()
# Usa sorted() aquí
fin_sorted = time.time()
tiempo_sorted = fin_sorted - inicio_sorted

print(f"Tiempo Bubble Sort: {tiempo_bubble:.6f} segundos")
print(f"Tiempo sorted():    {tiempo_sorted:.6f} segundos")
print(f"\nBubble Sort es {tiempo_bubble/tiempo_sorted:.2f}x más lento que sorted()")
print("\n💡 Conclusión: sorted() usa Timsort (O(n log n)), mucho más eficiente que Bubble Sort (O(n²))")

# %% [markdown]
# ## 🎯 Ejercicio Integrador: Fibonacci con Memoization
#
# Implementa Fibonacci de tres formas y compara rendimiento:
# 1. Recursivo simple (ineficiente)
# 2. Recursivo con memoization (eficiente)
# 3. Iterativo

# %%
# Recursivo simple (LENTO)
def fibonacci_recursivo(n):
    # TODO: Implementa versión recursiva básica
    pass

# Recursivo con memoization (RÁPIDO)
def fibonacci_memoization(n, memo={}):
    # TODO: Implementa con diccionario memo para guardar resultados previos
    pass

# Iterativo (MÁS RÁPIDO)
def fibonacci_iterativo(n):
    # TODO: Implementa versión iterativa
    pass

# Prueba de rendimiento
n = 30

print(f"Calculando Fibonacci({n})...\n")

# Mide cada implementación
inicio = time.time()
resultado_rec = fibonacci_recursivo(n)
tiempo_rec = time.time() - inicio

inicio = time.time()
resultado_memo = fibonacci_memoization(n)
tiempo_memo = time.time() - inicio

inicio = time.time()
resultado_iter = fibonacci_iterativo(n)
tiempo_iter = time.time() - inicio

print(f"Resultado: {resultado_rec}\n")
print(f"Recursivo simple:   {tiempo_rec:.6f} seg")
print(f"Con memoization:    {tiempo_memo:.6f} seg")
print(f"Iterativo:          {tiempo_iter:.6f} seg")
print(f"\n💡 La memoization reduce O(2^n) a O(n)!")

# %% [markdown]
# ## 🎓 Reflexión Final
#
# **Responde las siguientes preguntas**:
#
# 1. ¿Cuándo preferirías usar recursividad sobre iteración?
#
# 2. ¿Qué es la complejidad temporal y por qué es importante en Data Science?
#
# 3. ¿Cómo aplicarías funciones lambda en análisis de datos con Pandas?
#
# 4. ¿Qué ventaja tiene la memoization en algoritmos recursivos?
#
# ---
# **¡Excelente trabajo!** Has dominado conceptos matemáticos y algorítmicos fundamentales en Python. Estás preparado para enfrentar problemas complejos de Data Science. 🧠🚀
