# %% [markdown]
# ---
#
#
# # Sesión 01: Data Storytelling Express
# ## Reto: Análisis de Ventas en 15 Minutos
#
# **Objetivo**: Cargar datos, crear 3 visualizaciones clave y redactar una conclusión de negocio.
#
# ⏱️ **Tiempo límite: 15 minutos**
#
# ---

# %% [markdown]
# ---
#
# ## 📚 Sobre este Material
#
# Este material ha sido diseñado con el propósito de capacitar, actualizar y fortalecer las competencias en el manejo de datos con Python.
#
# ### 🤝 Compartir y Colaborar
#
# Este contenido es **libre para compartir, revisar, divulgar y mejorar**. Se promueve activamente su distribución en la comunidad para que más personas puedan beneficiarse y contribuir a su mejora continua. Tu feedback y sugerencias son siempre bienvenidos.
#
# ### 👨‍💻 Autor
#
# **Andrés Muñoz**
# *AI & Data Strategy Leader passionate about NLP, LLMs, and MLOps. Driving innovation with data*
#
# - 💼 LinkedIn: [in/amms1989](https://linkedin.com/in/amms1989)
# - 🐙 GitHub: [https://github.com/anguihero](https://github.com/anguihero)
#
# ---

# %% [markdown]
# ## Paso 1: Importar Librerías Necesarias
# Importa pandas, matplotlib, seaborn y cualquier otra librería que necesites.

# %%
# Importar librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Configuración de visualizaciones
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
# %matplotlib inline

# %% [markdown]
# ## Paso 2: Crear Dataset Ficticio de Ventas
# Genera un dataset simulado para el ejercicio (en un caso real, cargarías un archivo Excel aquí).

# %%
# Crear dataset ficticio de ventas
np.random.seed(42)
fechas = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
n_registros = 500

df_ventas = pd.DataFrame({
    'Fecha': np.random.choice(fechas, n_registros),
    'Categoria': np.random.choice(['Electrónica', 'Ropa', 'Alimentos', 'Hogar', 'Deportes'], n_registros),
    'Region': np.random.choice(['Norte', 'Sur', 'Este', 'Oeste'], n_registros),
    'Ingresos': np.random.uniform(50, 5000, n_registros).round(2),
    'Unidades': np.random.randint(1, 50, n_registros),
    'Vendedor': np.random.choice(['Ana', 'Carlos', 'María', 'Juan', 'Laura'], n_registros)
})

# Ordenar por fecha
df_ventas = df_ventas.sort_values('Fecha').reset_index(drop=True)

# Mostrar primeras filas
print("Vista previa del dataset:")
print(df_ventas.head())
print(f"\nForma del dataset: {df_ventas.shape}")
print(f"\nInformación del dataset:")
print(df_ventas.info())

# %% [markdown]
# ## Paso 3: Inspección Rápida de Datos
# Verifica valores nulos, estadísticas descriptivas y tipos de datos.

# %%
# TODO: Completa el código para inspeccionar el dataset

# Verifica valores nulos
print("Valores nulos:")
# Tu código aquí

# Estadísticas descriptivas
print("\nEstadísticas descriptivas:")
# Tu código aquí

# %% [markdown]
# ## Visualización 1: Evolución Temporal de Ingresos
# **Pregunta de negocio**: ¿Cuál es la tendencia de ventas a lo largo del tiempo?

# %%
# TODO: Crea un gráfico de líneas mostrando la evolución de ingresos por mes

# Pista: Agrupa por mes y suma los ingresos
# df_ventas['Mes'] = df_ventas['Fecha'].dt.to_period('M')

# Tu código aquí

plt.figure(figsize=(12, 6))
# Completa tu visualización
plt.title('Evolución de Ingresos Mensuales - 2023', fontsize=16, fontweight='bold')
plt.xlabel('Mes')
plt.ylabel('Ingresos Totales ($)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualización 2: Comparación de Ingresos por Categoría
# **Pregunta de negocio**: ¿Qué categorías generan más ingresos?

# %%
# TODO: Crea un gráfico de barras comparando ingresos por categoría

# Pista: Agrupa por categoría y suma los ingresos

# Tu código aquí

plt.figure(figsize=(10, 6))
# Completa tu visualización
plt.title('Ingresos Totales por Categoría de Producto', fontsize=16, fontweight='bold')
plt.xlabel('Categoría')
plt.ylabel('Ingresos Totales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualización 3: Top Performers - Ranking de Vendedores
# **Pregunta de negocio**: ¿Quiénes son los vendedores más exitosos?

# %%
# TODO: Crea un gráfico de barras horizontales con el ranking de vendedores

# Pista: Agrupa por vendedor, suma ingresos y ordena

# Tu código aquí

plt.figure(figsize=(10, 6))
# Completa tu visualización
plt.title('Ranking de Vendedores por Ingresos Totales', fontsize=16, fontweight='bold')
plt.xlabel('Ingresos Totales ($)')
plt.ylabel('Vendedor')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Paso 4: Conclusión de Negocio (Executive Summary)
# Redacta un párrafo conciso con:
# - El insight principal descubierto
# - Implicaciones para el negocio
# - Una recomendación accionable

# %% [markdown]
# ### 📊 Executive Summary
#
# **TODO: Completa tu conclusión aquí**
#
# ```
# Escribe tu análisis aquí. Ejemplo:
#
# "Tras el análisis de las ventas 2023, se identificó que...
# Las implicaciones principales son...
# Recomendamos..."
# ```

# %% [markdown]
# ## 🎯 Reflexión Final
# - ¿Lograste completar el reto en 15 minutos?
# - ¿Qué aprendiste sobre la importancia de la síntesis rápida?
# - ¿Qué mejorarías para la próxima vez?
#
# ---
# **¡Excelente trabajo!** Has completado tu primer ejercicio de Data Storytelling Express. 🚀
