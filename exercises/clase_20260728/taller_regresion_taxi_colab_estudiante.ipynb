# %% [markdown]
# # Taller Estudiante: Regresion con Taxi Price Prediction
#
# Objetivo: seguir un flujo realista para entrenar, comparar y validar modelos de regresion.
#
# Dataset original: https://www.kaggle.com/datasets/denkuznetz/taxi-price-prediction

# %% [markdown]
# ## Contexto de las particiones
#
# Particiones dadas por el profesor:
# - Desarrollo 90%: taxi_dev_90.csv
# - Validacion 10%: taxi_validation_10.csv
#
# Resumen de datos:
# - Filas originales: 1000
# - Filas con target no nulo usadas para modelado: 951
# - Excluidas por Trip_Price nulo: 49
# - Desarrollo 90%: 855
# - Validacion 10%: 96

# %% [markdown]
# ## 1) Preparacion en Google Colab
#
# Primero trabaja en Google Colab.
#
# Opciones de carga de CSV:
# 1. Leer desde URL RAW en GitHub (si esta disponible).
# 2. Subir archivos a la sesion de Colab y leer desde /content.

# %%
# TODO: Instalar dependencias si hace falta
# !pip -q install pandas numpy scikit-learn matplotlib seaborn

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# %%
# TODO: Completar rutas o URLs
DEV_URL = ""
VAL_URL = ""
DEV_LOCAL_PATH = "/content/taxi_dev_90.csv"
VAL_LOCAL_PATH = "/content/taxi_validation_10.csv"


RANDOM_STATE = 42
TARGET_COL = "Trip_Price"

# %% [markdown]
# ## 2) Validar carga y lectura
#
# Debes demostrar que los datos quedaron bien cargados y bien leidos.

# %% [markdown]
# ## 3) EDA: analisis exploratorio descriptivo
#
# Tareas esperadas:
# - Distribucion del target.
# - Estadisticos descriptivos.
# - Datos ausentes.
# - Atipicos en variables numericas (por ejemplo IQR).
# - Relacion entre variables y target.

# %% [markdown]
# ## 4) Preparacion de datos
#
# Recomendacion de buenas practicas:
# - Modularizar en funciones.
# - Usar Pipeline y ColumnTransformer.
# - Imputar nulos por tipo de variable.
# - Escalar numericas.
# - Codificar categoricas.

# %% [markdown]
# ## 5) Entrenar, medir y comparar modelos
#
# Crea una tabla benchmarking con MAE, RMSE y R2 para varios modelos.

# %% [markdown]
# ## 6) Seleccion del mejor modelo
#
# Selecciona el mejor segun RMSE (u otro criterio que justifiques).

# %% [markdown]
# ## 7) Evaluacion final sobre validacion 10%
#
# Crea una funcion automatizada que reciba el modelo ajustado y evalue el desempeno final en taxi_validation_10.csv.

# %% [markdown]
# ## 8) Cierre
#
# Incluye en tus conclusiones:
# - Que modelo gano y por que.
# - Si hay sobreajuste (comparando train/test si lo calculaste).
# - Limites del enfoque y mejoras futuras.
# - Impacto practico de los errores (MAE/RMSE).
