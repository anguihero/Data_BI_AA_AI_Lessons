# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install pandas numpy
# busca si lo tengo instalado, si no lo tengo, lo busca y si existe lo descarga y lo instala (las dependencias)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\anmmu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
