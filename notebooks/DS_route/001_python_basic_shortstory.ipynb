# %% [markdown]
# # BASES DE PYTHON
#
#
#
# ---

# %% [markdown]
# ---
#
# ## 📚 Sobre este Material
#
# Este material ha sido diseñado con el propósito de **capacitar, actualizar y practicar** conceptos **fundamentales mínimos** para comenzar a programar en Python con miras a la ciencia de datos. Cada sección introduce el concepto, muestra la sintaxis esencial y concluye con un ejemplo breve que puedes ejecutar y modificar a tu gusto..
#
# ### 🤝 Compartir y Colaborar
#
# Este contenido es **libre para compartir, revisar, divulgar y mejorar**. Se promueve activamente su distribución en la comunidad para que más personas puedan beneficiarse y contribuir a su mejora continua. Tu feedback y sugerencias son siempre bienvenidos.
#
# ### 👨‍💻 Autor
#
# **Andrés Muñoz**
# *AI & Data Strategy Leader passionate about NLP, LLMs, and MLOps. Driving innovation with data*
#
# - 💼 LinkedIn: [in/amms1989](https://linkedin.com/in/amms1989)
# - 🐙 GitHub: [https://github.com/anguihero](https://github.com/anguihero)
#
# ---

# %% [markdown]
# ### Tabla de Contenidos
#
# 1. [Jupyter Notebook](#1-jupyter-notebook)
# 2. [Variables](#2-variables)
# 3. [Booleanos](#3-booleanos)
# 4. [Tipos Numéricos](#4-tipos-numericos)
# 5. [Cadenas de Texto](#5-cadenas-de-texto)
# 6. [Rangos](#6-rangos)
# 7. [Listas](#7-listas)
# 8. [Tuplas](#8-tuplas)
# 9. [Diccionarios](#9-diccionarios)
# 10. [Condicionales](#10-condicionales)
# 11. [Bucles](#11-bucles)
# 12. [Funciones](#12-funciones)
# 13. [Lambda y Map](#13-lambda-y-map)
# 14. [Errores y excepciones](#14-Errores-y-excepciones)
# 15. [Reto Final Integrador](#Reto-Final-Integrador)
# 16. [Bibliografía y recursos](#bibliografia)

# %% [markdown]
# ---
# ## 1. Jupyter Notebook
#
# **Jupyter Notebook** combina código ejecutable, texto y visualizaciones en un mismo documento.
# Funciona por **celdas independientes**: las de código se ejecutan con `Shift + Enter`, las de texto usan formato Markdown.
#
# | Acción | Atajo |
# |---|---|
# | Ejecutar celda | `Shift + Enter` |
# | Nueva celda arriba | `A` (modo comando) |
# | Nueva celda abajo | `B` (modo comando) |
# | Eliminar celda | `DD` (modo comando) |
# | Modo comando | `Esc` |
# | Modo edición | `Enter` |
#
# > ⚠️ Las celdas pueden ejecutarse en cualquier orden. Siempre verifica el orden lógico antes de compartir tu notebook.

# %%
# esto es una celda de codigo
# el resultado de la ultima linea se muestra automaticamente en el output
1 + 1

# %% [markdown]
# ### 🏋️ Ejercicio 1 — Jupyter Notebook
#
# 1. Crea una nueva celda **debajo** de esta usando el atajo de teclado.
# 2. En esa celda escribe `print("Mi primer notebook")` y ejecútala.
# 3. Convierte esta celda (la del ejercicio) a tipo **Markdown** usando el menú y escribe tu nombre.

# %%
# tu codigo aqui

# %% [markdown]
# ---
# ## 2. Variables
#
# Una **variable** es una etiqueta que apunta a un objeto en memoria.
# Python tiene **tipado dinámico**: no se declara el tipo, Python lo infiere.
#
# ```python
# nombre_variable = valor   # asignación con =
# print(nombre_variable)    # mostrar en pantalla
# type(nombre_variable)     # conocer el tipo de dato
# ```
#
# **Reglas de nomenclatura:** sin espacios, no empezar con número, sensible a mayúsculas.

# %%
s1um_1int = 1

# %%
# asignar diferentes tipos de informacion a variables
saludo = "Hola Mundo"
fecha_hoy = 20260612 # tipos fecha .pandas .datetime 
precio = 99.9

print(saludo)
print(type(saludo))
print(fecha_hoy)
print(type(fecha_hoy))
print(precio)
print(type(precio))

# %% [markdown]
# ### 🏋️ Ejercicio 2 — Variables
#
# Crea tres variables con tu información personal:
# - `mi_nombre` → tu nombre completo (texto)
# - `mi_edad` → tu edad (número entero)
# - `mi_ciudad` → la ciudad donde vives (texto)
#
# Muestra en pantalla cada variable junto con su tipo usando `print()` y `type()`.

# %%
# tu codigo aqui
mi_nombre = "Andres"
mi_edad = 36
mi_ciudad = "Bogota"

print(mi_nombre, type(mi_nombre))
print(mi_edad, type(mi_edad))
print(mi_ciudad, type(mi_ciudad))

# %% [markdown]
# ---
# ## 3. Booleanos
#
# Los **booleanos** representan verdad (`True`) o falsedad (`False`).
# Son el resultado de cualquier comparación lógica.
#
# | Operador | Significado |
# |---|---|
# | `==` | igual a |
# | `!=` | diferente de |
# | `>` `<` | mayor / menor |
# | `>=` `<=` | mayor o igual / menor o igual |
#
# En operaciones numéricas: `True = 1`, `False = 0`.

# %%
# asignar booleanos directamente
activo = True
print(activo, type(activo))

# %%
# booleano como resultado de comparacion
resultado = 10 > 5
print(resultado, type(resultado))

# %%
# operaciones con booleanos (True=1, False=0)
print(True + True)   # 2
print(True * False)  # 0

# %% [markdown]
# ### 🏋️ Ejercicio 3 — Booleanos
#
# Dados los valores `a = 15` y `b = 30`:
# 1. Evalúa y muestra si `a` es mayor que `b`.
# 2. Evalúa y muestra si el doble de `a` es igual a `b`.
# 3. Suma los dos resultados booleanos anteriores. ¿Qué número obtienes?

# %%
# tu codigo aqui
a = 15
b = 30

res_1 = a>b
res_2 = (a * 2) ==b
print(res_1)
print(res_2)
print(res_1 + res_2)

# %% [markdown]
# ---
# ## 4. Tipos Numéricos
#
# Python maneja principalmente dos tipos numéricos:
# - **`int`** — enteros: `20`, `-5`, `1000`
# - **`float`** — decimales: `3.14`, `-0.5`, `2.0`
#
# | Operador | Operación | Ejemplo | Resultado |
# |---|---|---|---|
# | `+` | Suma | `5 + 3` | `8` |
# | `-` | Resta | `5 - 3` | `2` |
# | `*` | Multiplicación | `5 * 3` | `15` |
# | `/` | División | `7 / 2` | `3.5` |
# | `//` | División entera | `7 // 2` | `3` |
# | `**` | Potencia | `2 ** 3` | `8` |
# | `%` | Módulo (residuo) | `7 % 2` | `1` |

# %%
# numeros enteros
num_a = 10

print(num_a)
print(type(num_a))

# %%
# numeros flotantes
num_b = 3.0

print(num_b)
print(type(num_b))

# %%
# conversion entre tipos
entero = 7
print(entero, type(entero))

decimal = float(entero)   # int -> float
print(decimal, type(decimal))

es_igual = entero == decimal
print(es_igual)

# %%
print(round(3.8))   # redondeo

# %%
# operaciones aritmeticas basicas
num_a = 10
num_b = 3

print(num_a)
print(type(num_a))

print(num_b)
print(type(num_b))

# %%
print('suma       :', num_a + num_b)

# %%
print('resta      :', num_a - num_b)

# %%
print('division   :', num_a / num_b)   # resultado float

# %%
print('div entera :', num_a // num_b)  # solo la parte entera

# %%
print('modulo     :', num_a % num_b)   # residuo

# %%
print('potencia   :', num_a ** num_b)

# %% [markdown]
# ### 🏋️ Ejercicio 4 — Tipos Numéricos
#
# Tienes una tienda: vendes **17 productos a $8.500** cada uno.
# 1. Calcula el **total de ventas**.
# 2. Si el **IVA es del 19%**, calcula el valor del IVA y el **total con IVA**.
# 3. ¿Cuántos productos enteros puedes comprar con **$50.000**? (usa `//`)
# 4. ¿Cuánto dinero te sobra? (usa `%`)

# %%
# tu codigo aqui
cantidad = 17
precio_unitario = 8500
iva = 0.19
presupuesto = 50000

total_ventas = cantidad * precio_unitario
valor_iva = total_ventas * iva
total_con_iva = valor_iva + total_ventas
productos_que_compro = presupuesto // (precio_unitario*(1+iva))
dinero_sobrante = presupuesto % (precio_unitario*(1+iva))

print('Total ventas :', total_ventas)
print('IVA          :', valor_iva)
print('Total + IVA  :', total_con_iva)
print('Productos    :', productos_que_compro)
print('Sobrante     :', dinero_sobrante)

# %% [markdown]
# ---
# ## 5. Cadenas de Texto
#
# Los **strings** son secuencias inmutables de caracteres delimitados por comillas simples `'...'`, dobles `"..."` o triple `"""..."""`.
#
# **Operadores:**
# - `+` → concatenar: `"Hola" + " mundo"`
# - `*` → repetir: `"paz_" * 3`
#
# **Métodos más usados:**
# ```python
# .lower()      # todo en minúsculas
# .upper()      # todo en mayúsculas
# .strip()      # quitar espacios extremos
# .replace()    # reemplazar texto
# .split()      # dividir en lista
# .startswith() # verifica inicio
# .find()       # posición de patrón
# len()         # longitud
# ```

# %%
# Ejemplo con comillas simples
texto_simple = 'Hola, esto es un texto básico.'
print(texto_simple, type(texto_simple))

# %%
# Ejemplo con comillas dobles
texto_doble = "Hola, esto también es un texto básico."
print(texto_doble, type(texto_doble))

# %%
# ¿Por qué importan ambas? Para evitar conflictos:
texto_con_comilla_dentro = "I'm learning Python"  # Aquí las comillas dobles salvan el día
print(texto_con_comilla_dentro, type(texto_con_comilla_dentro))

# %%
# Ejemplo con triples comillas dobles (las más comunes para esto)
texto_multilinea = """Este es un texto
que se divide en varias líneas
sin necesidad de usar trucos."""
print(texto_multilinea)
print(type(texto_multilinea))

# %%
# Ejemplo con triples comillas simples
texto_multilinea_simple = '''También funciona exactamente igual
si prefieres usar tres comillas
simples seguidas.'''

print(texto_multilinea_simple)
print(type(texto_multilinea_simple))

# %%
# 1. Una sola comilla (simple o doble)
opcion_a = 'el mismo texto'
opcion_b = "el mismo texto"


# Imprimimos los resultados
print('variable a : ',opcion_a)
print('variable b : ',opcion_b)

# comparar si son misma informacion
comparacion_a_b = opcion_a == opcion_b
print('son iguales var a y b : ',comparacion_a_b)

# %%
# 2. Triple comilla (simple o doble)
opcion_c = '''el mismo texto
pero con triple comilla'''

opcion_d = """el mismo texto
pero con triple comilla"""

# Imprimimos los resultados
print('variable c : ',opcion_c)
print('variable d : ',opcion_d)

# comparar si son misma informacion
comparacion_c_d = opcion_c == opcion_d
print('son iguales var c y d : ',comparacion_c_d)

# %%
# 3. comparar unica comilla con Triple comilla
opcion_e = 'este texto tiene\nsalto de linea'

opcion_f = """este texto tiene
salto de linea"""

# Imprimimos los resultados
print('variable e : ',opcion_e)
print('variable f : ',opcion_f)

# comparar si son misma informacion
comparacion_e_f = opcion_e == opcion_f
print('son iguales var e y f : ',comparacion_e_f)

# %%
# creacion y operaciones basicas
txt_a = 'Hola'
txt_b = 'Mundo'

print('-'*50) # lineas de division
print(txt_a+txt_b) # concatenacion
print(txt_a + ' ' + txt_b)   # concatenacion

print('-'*50)
print('paz_' * 3)             # repeticion

print('-'*50)
print(len(txt_a + txt_b))     # longitud total

# %%
# El método .format()

nombre_usuario = "Carlos"
curso_inscrito = "Python desde Cero"
precio_oferta = 19.99

# 2. Creamos la plantilla con llaves vacías {}
plantilla = """
¡Hola, {}! 

Gracias por unirte a nuestra plataforma. 
Te has inscrito correctamente al curso: '{}'.

El total de tu compra fue de ${}. ¡Ya puedes comenzar a aprender!
"""

# 3. Rellenamos la plantilla en orden
mensaje_final = plantilla.format(nombre_usuario, curso_inscrito, precio_oferta)

print(mensaje_final)

# %%
# El método .format()

ganador = "Carlos"
premio = "una Laptop"

# El orden en .format() es (ganador, premio) -> ganador es 0, premio es 1
frase = "El cliente {0} ha ganado {1}. ¡Felicidades {0}!".format(ganador, premio)

print(frase)

# %%
# Las f-strings (o formatted string literals)

ganador = "Carlos"
premio = "una Laptop"

# El orden en .format() es (ganador, premio) -> ganador es 0, premio es 1
frase = f"El cliente {ganador} ha ganado {premio}. ¡Felicidades {ganador}!"

print(frase)

# %%
# metodos de texto
txt = '   Poverty Is The   '
print(txt)
print(txt.strip())             # sin espacios extremos
print(txt.strip().lower())     # encadenando metodos # pasar todo a minusculas
print(txt.strip().upper())      # encadenando metodos # pasar todo a minusculas
# title()	Converts the first character of each word to upper case
print(txt.title())      # encadenando metodos # pasar todo a minusculas
# capitalize()	Converts the first character to upper case
print(txt.capitalize())
# capitalize()	Converts the first character to upper case
print(txt.strip().capitalize())

# %%
# metodos de texto
txt = '   Poverty Is The   '
print(txt)
# startswith()	Returns true if the string starts with the specified value
print(txt.startswith('Po'))  # comienza con?
# startswith()	Returns true if the string starts with the specified value
print(txt.strip().startswith('Po'))  # comienza con?

# %%
# metodos de texto
txt = '   Poverty Is The   '
print(txt)
# endswith()	Returns true if the string ends with the specified value
print(txt.endswith('the'))  # comienza con?
# endswith()	Returns true if the string ends with the specified value
print(txt.strip().endswith('the'))  # comienza con?
print(txt.lower().strip().endswith('the'))

# %%
# caracteres especiales y rutas
print('Linea 1\nLinea 2')                          # salto de linea \n

# %%
print(r'C:\Users\nombre\archivo.ipynb')            # raw string para rutas

# %%
print('C:\\Users\\nombre\\archivo.ipynb')            # escapando

# %% [markdown]
# ### 🏋️ Ejercicio 5 — Cadenas de Texto
#
# Tienes el siguiente texto sucio: `"   DATA SCIENCE con python   "`
#
# 1. Quita los espacios extremos.
# 2. Conviértelo a formato título (primera letra de cada palabra en mayúscula).
# 3. Verifica si el texto (limpio) **termina con** `"python"` — ¿es True o False?
#    *(Pista: asegúrate de trabajar en el mismo tipo de capitalización)*
# 4. Usando f-string, imprime: `"El texto limpio tiene X caracteres"`

# %%
# tu codigo aqui
txt_sucio = '   DATA SCIENCE con python   '

txt_limpio = txt_sucio.strip()
txt_titulo = txt_limpio.title()
termina_python = txt_titulo.endswith('python')

print(txt_sucio)
print(txt_limpio)
print(txt_titulo)
print(termina_python)
print(f'El texto limpio tiene {len(txt_limpio)} caracteres')

# %% [markdown]
# ---
# ## 6. Rangos
#
# Un **rango** (`range`) genera una secuencia de números enteros sin almacenarlos todos en memoria.
#
# ```python
# range(fin)              # 0, 1, 2, ..., fin-1
# range(inicio, fin)      # inicio, inicio+1, ..., fin-1
# range(inicio, fin, paso) # con saltos
# ```
#
# > El índice en Python **siempre empieza en 0** y el límite final es **excluido**.

# %%
rango_cinco = range(5)
print(rango_cinco)
print(type(rango_cinco))

# %%
# range con un argumento: del 0 al n-1

rango = range(5)
print(rango)
print(type(rango))

# estructura for : para recorrer uno a uno los elementos del rango

# para cada i (elemento) dentro del rango (iterable) realice:
for i in rango:
    print('-'*10)
    print(i)   # 0 1 2 3 4
    
print('esta no esta dentro de la iteracion')

# %%
# range con un argumento: del 0 al n-1


rango = range(0,5)
print(rango)
print(type(rango))

for i in rango:
    print(i)   # 0 1 2 3 4
print()

# %%
# range con inicio, fin y paso

rango = range(0, 20, 5)
print(rango)
print(type(rango))


for i in rango:
    print(i, end=' ')   # 0 5 10 15
print()

# %% [markdown]
# ### 🏋️ Ejercicio 6 — Rangos
#
# 1. Crea un rango que genere los números del **10 al 50** de 10 en 10 y muéstralos en pantalla.
# 2. Usando un `range` y un `for`, calcula e imprime la **tabla de multiplicar del 7** (del 7×1 al 7×10).
#    Formato esperado: `7 x 1 = 7`

# %%
# tu codigo aqui

# punto 1
for i in range( 10, 51, 10):
    print(i, end=' ') # end del print ... que pone al final del print
print()

# punto 2
for i in range( 1,11 ):
    print(f'7 x {i} = {7*i}')

# %% [markdown]
# ---
# ## 7. Listas
#
# Una **lista** es una colección **ordenada y mutable** de elementos.
# Se delimita con corchetes `[ ]` y puede mezclar tipos de datos.
#
# ```python
# lista[0]      # primer elemento (índice 0)
# lista[-1]     # último elemento
# lista[1:4]    # slice: elementos del índice 1 al 3
# len(lista)    # cantidad de elementos
# ```
#
# **Métodos clave:**
# ```python
# .append(x)    # agregar al final
# .insert(i,x)  # insertar en posición i
# .remove(x)    # eliminar primer x
# .pop(i)       # eliminar por posición
# .index(x)     # posición de x
# x in lista    # verificar si existe
# ```

# %%
ganas_de_trabajar = []

print(ganas_de_trabajar)
print(type(ganas_de_trabajar))

# %%
booleanos = [True, False, False,True]
print(booleanos)
print(type(booleanos))

# %%
frutas = ['manzana', 'pera', 'uva', 'mango']
print(frutas)
print(type(frutas))

# %%
numeros = [10, 20, 30]
print(numeros)
print(type(numeros))

# %%
varios = [10,True, False, 'pera', 'uva',20,True, False, 30]
print(varios)
print(type(varios))

# %%
# crear y acceder a listas
frutas = ['manzana', 'pera', 'uva', 'mango']
print(frutas[0])      # primer elemento - es la posicion 0
print(frutas[3])   
print(frutas[-1])     # ultimo elemento
print(frutas[1:3])    # slice
print(len(frutas))    # cantidad de elementos
print('uva' in frutas)  # verificar existencia

# %%
# crear y acceder a listas
frutas = ['manzana', 'pera', 'uva', 'mango']
frutas.index('uva') # index()	Returns the index of the first element with the specified value

# %%
# mutar listas
numeros = [10, 20, 30]

print(numeros)
print('-'*50)

numeros.append(40)      # agregar al final
numeros.insert(1, 15)   # insertar en posicion 1
print(numeros)

print('-'*50)

   # eliminar el 15
print(numeros)


print('-'*50)

# recorrer una lista
for n in numeros:
    print(n, end=' ')

# %% [markdown]
# ### 🏋️ Ejercicio 7 — Listas
#
# Tienes la lista de invitados a una fiesta: `['Hugo', 'Ivan', 'Ana', 'Lara', 'Leo']`
#
# 1. Agrega tu nombre al **final** de la lista.
# 2. Inserta `'VIP'` en la **posición 0** (al inicio).
# 3. Elimina `'Ivan'` de la lista.
# 4. Muestra en pantalla el número total de invitados con el mensaje: `"Total invitados: X"`
# 5. Recorre la lista e imprime cada nombre.

# %%
# tu codigo aqui
invitados = ['Hugo', 'Ivan', 'Ana', 'Lara', 'Leo']

# punto 1
invitados.append( 'Andres')
# punto 2
invitados.insert(0,'VIP')
# punto 3
invitados.remove('Ivan')
# punto 4
print(f'Total invitados: {len(invitados)}')
# punto 5
for nombre in invitados:
    print(nombre)

# %% [markdown]
# ---
# ## 8. Tuplas
#
# Las **tuplas** son colecciones **ordenadas e inmutables**.
# Se delimitan con paréntesis `( )` o simplemente con comas.
# Al ser inmutables, son ideales para datos que no deben cambiar (coordenadas, fechas, credenciales).
#
# **Empaquetado y desempaquetado:**
# ```python
# fecha = 20, 'Agosto', 2026        # empacar
# dia, mes, anio = fecha            # desempacar
# ```

# %%
# crear tuplas
colores = ('rojo', 'verde', 'azul')
print(colores, type(colores))
print(colores[0])       # acceso por indice
print(len(colores))     # longitud

# %%
# empaquetado y desempaquetado
fecha = 12, 'Junio', 2026     # tupla empaquetada
print(fecha)

dia, mes, anio = fecha         # desempacar en variables individuales
print(f'Hoy es {dia} de {mes} del {anio}')

# %%
# tupla anidada
persona = ('Andres', (30, 'Bogota'))
print(persona[1][1])   # acceder a elementos anidados
print(len(persona))

# %% [markdown]
# ### 🏋️ Ejercicio 8 — Tuplas
#
# 1. Crea una tupla con tus datos personales: `(nombre, edad, ciudad)`.
# 2. Desempácala en tres variables individuales e imprime cada una.
# 3. Intenta modificar el primer elemento de la tupla. ¿Qué error obtienes? (Escribe el nombre del error en un comentario)

# %%
# tu codigo aqui
mis_datos = ( 'Andres','36' ,'Bogota' )     # nombre, edad, ciudad

nombre, edad, ciudad = mis_datos
print(nombre)
print(edad)
print(ciudad)

# %%
# descomentar para ver el error
mis_datos[0] = 'otro nombre'   # Error: ___________TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ---
# ## 9. Diccionarios
#
# Un **diccionario** es una colección de pares `clave → valor`.
# Se accede al valor por **clave** (no por posición). Se delimita con llaves `{ }`.
#
# ```python
# dicc = {'clave': valor}
# dicc['clave']          # acceso por clave
# dicc.get('clave')      # acceso seguro (no genera error si no existe)
# dicc['nueva_clave'] = nuevo_valor   # agregar / modificar
# dicc.keys()            # todas las claves
# dicc.values()          # todos los valores
# dicc.items()           # pares clave-valor (para iterar)
# ```

# %%
credenciales = {

}

print(credenciales)
print(type(credenciales))

# %%
credenciales = {
    'usuario' : "hacker",
    'contrasenia' : 'segura',
    'tiempo' : 186
}

print(credenciales)
print(type(credenciales))
print(len(credenciales ))

# %%
# crear y acceder a diccionarios
estudiante = {
    'nombre': 'Andres',
    'edad': 25,
    'materias': ['Python', 'Estadistica', 'Machine Learning']
}

print(estudiante['nombre'])         # acceso directo
print(estudiante.get('edad'))       # acceso seguro
print(estudiante['materias'][2])    # acceso a elemento de lista dentro del dict

# %%
# agregar, modificar e iterar
estudiante['ciudad'] = 'Bogota'    # agregar clave nueva
estudiante['edad'] = 26            # modificar valor existente

# iterar sobre un diccionario
for clave, valor in estudiante.items():
    print(f'{clave}: {valor}')

# %% [markdown]
# ### 🏋️ Ejercicio 9 — Diccionarios
#
# Crea un diccionario `producto` con las claves: `'nombre'`, `'precio'`, `'stock'`.
#
# 1. Agrega una clave `'categoria'` con el valor que quieras.
# 2. Actualiza el precio aplicando un descuento del 10%.
# 3. Recorre e imprime todos los pares clave-valor con el formato: `clave --> valor`

# %%
# tu codigo aqui
producto = {
    'nombre': 'Laptop',
    'precio': 3500000,
    'stock': 10
}

# punto 1
producto['categoria'] = 'tecnologia' 
# punto 2
producto['precio'] = producto['precio']*(1-.1)
# punto 3
for clave, valor in producto.items():
    print('-'*10)
    print(f'{clave} --> {valor}')

# %% [markdown]
# ---
# ## 10. Condicionales
#
# Los **condicionales** permiten ejecutar diferentes bloques según una condición lógica.
#
# ```python
# if condicion_1:
#     # bloque si condicion_1 es True
# elif condicion_2:
#     # bloque si condicion_2 es True
# else:
#     # bloque si ninguna condición fue True
# ```
#
# > ⚠️ La **indentación** (sangría de 4 espacios) define el bloque de código — es obligatoria en Python.

# %%
# Ejemplo básico: Alerta de batería baja
porcentaje_bateria = 26

# si el porcentaje de bateria es MENOR O IGUAL a 15 entonces
if porcentaje_bateria <= 20:
    # si se cumple condicion muestra en pantalla
    print("¡Advertencia! Batería baja. Conecta el cargador.")

# como no está indentado siempre lo muestra en pantalla
print("El teléfono sigue encendido...")

# %%
# Ejemplo básico: Validación de contraseña
contrasenia_correcta = "python123"
contrasenia_ingresada = "html456"

# si ingresada es igual a correcta entonces 
if contrasenia_ingresada == contrasenia_correcta:
    # si respuesta fue verdadera muestra mensaje
    print("¡Acceso concedido! Bienvenido.")
# en caso de que no fuera el resultado de la validacion del if verdadera entonces 
else:
    # muestra mensaje
    print("Contraseña incorrecta. Inténtalo de nuevo.")

# %%
# ejemplo basico: clasificar edad
edad = 2

if edad >= 18:
    print('Mayor de edad')
elif edad >= 13: # funciona igual que IF y se utilice para evaluaciones de casos especificos intermedios (despues del if y antes del else)
    print('Adolescente')
else:
    print('Niño')

# %%
# en el mundial pasan los dos primeros de cada grupo, el primero es cabeza de llave, el segundo no va a serr cabeza
# los mejores terceros juegan de repchaje 16os

equipo = 1
ganador = True

if equipo < 3: # primeros y segundos
    print('el equipo clasifica 8vos')
    if equipo == 1:
        print('el equipo va a ser cabeza')
        if ganador:
            print('avanza a 4tos')
        else:
            print('queda eliminado')
    else:
        print('el equipo va a ser cola')
        if ganador == True:
            print('avanza a 4tos')
        else:
            print('queda eliminado')
elif equipo < 4:
    print('el equipo va a 16os')
    if ganador == True:
        print('avanza a 8vos')
    else:
        print('queda eliminado')
elif equipo == 4:
    print('el equipo no clasifica, quedó eliminado')
    print(' se fue volando para su pais')
else:
    print('la posición seleccionada es incorrecta, escoja un numero entre 1 y 4')

# %%
# ejemplo con variables
hora_llegada = 11.5   # 7:30 AM
hora_clase = 9.0
hora_fin = 12.0

if hora_llegada <= hora_clase:
    estado = 'A tiempo'
elif hora_llegada < hora_fin:
    estado = 'Tarde'
else:
    estado = 'No asistio'

print(f'El estudiante llegó a las {hora_llegada}: {estado}')

# %% [markdown]
# ### 🏋️ Ejercicio 10 — Condicionales
#
# Crea un programa que evalúe una **nota académica** (0 a 100) y la clasifique:
#
# | Rango | Clasificación |
# |---|---|
# | 90 – 100 | Sobresaliente |
# | 70 – 89 | Aprobado |
# | 60 – 69 | En riesgo |
# | 0 – 59 | Reprobado |
#
# Prueba con al menos 3 valores distintos.

# %%
# tu codigo aqui
nota = 100  # cambia este valor para probar

if nota >= 90:
    clasificacion = 'Sobresaliente'
elif nota >= 70:
    clasificacion = 'Aprobado'
elif nota >= 60:
    clasificacion = 'En riesgo'
else:
    clasificacion = 'Reprobado'

print(f'Nota: {nota} → {clasificacion}')

# %% [markdown]
# ---
# ## 11. Bucles
#
# Los **bucles** permiten ejecutar un bloque de código repetidamente.
#
# ### `for` — iterar sobre una colección
# ```python
# for elemento in coleccion:
#     # bloque que se repite
# ```
#
# ### `while` — iterar mientras se cumpla una condición
# ```python
# while condicion:
#     # bloque que se repite
#     # importante: actualizar la condicion para evitar loop infinito
# ```
#
# | Palabra | Efecto |
# |---|---|
# | `break` | Sale del bucle inmediatamente |
# | `continue` | Salta a la siguiente iteración |
# | `pass` | No hace nada (marcador de posición) |

# %%
# for sobre lista
materias = ['Python', 'Estadistica', 'SQL', 'Machine Learning']

# para cada elemento del iterable realice :
for materia in materias:
    # muestre en pantalla {f-string == .format}  
    print(f'- {materia}')
    # print('- {0}'.format(materia)) # misma forma de hacerlo pero usando format()

# %%
# for sobre lista
materias = ['Python', 'Estadistica', 'SQL', 'Machine Learning']

# for con enumerate para tener indice y valor
for i, materia in enumerate(materias):
    print('-'*50)
    print(f'{i+1}. {materia}')

    print('progreso : {}%'.format(((i+1)*100)/len(materias)))

# %%
# break y continue
for n in range(10):
    if n == 3:
        continue    # salta el 3
    if n == 7:
        break       # detiene el bucle
    print(n, end=' ')

# %%
# while
contador = 0
while contador < 5:
    print(f'Vuelta #{contador}')
    contador += 1   # actualizar el contador (evita loop infinito)

print('Listo!')

# %% [markdown]
# ### 🏋️ Ejercicio 11 — Bucles
#
# Tienes una lista de precios: `[12000, 8500, 45000, 3200, 97000, 560, 23000]`
#
# 1. Con un **`for`**, imprime solo los precios **mayores a 10.000** con el mensaje: `"Precio alto: $X"`
# 2. Calcula la **suma total** de todos los precios de la lista.
# 3. Con un **`while`**, simula un cajero que descuenta `5.000` de un saldo inicial de `25.000` hasta que no alcance para otro descuento. Imprime el saldo en cada vuelta.

# %%
# tu codigo aqui
precios = [12000, 8500, 45000, 3200, 97000, 560, 23000]

# punto 1 y 2
total = 0
for p in precios:
    if p > 10000:
        print(f'Precio alto: ${p}')
    total += p
print(f'Total: ${total}')

print('---')

# %%
# donde cambiaria el codigo para mostrar los que son mas bajos a 5000. cambiar el mensaje

# tu codigo aqui
precios = [12000, 8500, 45000, 3200, 97000, 560, 23000]

# punto 1 y 2
total = 0
for precio in precios:
    if precio < 5000: #
        print(f'Precio bajo: ${precio}')
    total += precio
print(f'Total: ${total}')

print('---')

# %%
# punto 3
saldo = 25000
descuento = 2100
while saldo >= descuento:
    saldo -= descuento
    print(f'Saldo restante: ${saldo}')
print('Saldo insuficiente para otro descuento')

# %% [markdown]
# ---
# ## 12. Funciones
#
# Las **funciones** son bloques de código reutilizables que reciben entradas (argumentos) y devuelven una salida (`return`).
#
# ```python
# def nombre_funcion(arg1, arg2):
#     """Descripción breve de la función."""
#     resultado = arg1 + arg2
#     return resultado
# ```
#
# | Combinación | Descripción |
# |---|---|
# | Sin args, sin return | Solo ejecuta acciones |
# | Con args, sin return | Usa entradas, no devuelve |
# | Con args, con return | La más común en Data Science |

# %%
# definicion de una funcion
# funcion sin argumentos
def saludar():
    print('Hola, equipo de Data Science!')

# %%
saludar()
saludar()
saludar()
saludar()
saludar()

# %%
# funcion con argumentos y retorno
def calcular_potencia(base : int, exponente : int):
    """Retorna base elevado a exponente."""
    return base ** exponente

# %%
print(calcular_potencia(2, 8)) # 2x2x2x2x2x2x2x2

print(calcular_potencia(base=10, exponente=3)) # 10x10x10

# %%
# funcion con multiples retornos (via tupla)
def estadisticas_basicas(lista_numeros : list):
    """Retorna el minimo, maximo y promedio de una lista."""
    minimo = min(lista_numeros)
    maximo = max(lista_numeros)
    promedio = sum(lista_numeros) / len(lista_numeros)
    return minimo, maximo, promedio

# %%
datos = [4, 7, 2, 9, 1, 5]
mn, mx, prom = estadisticas_basicas(datos)
print(f'Min: {mn} | Max: {mx} | Promedio: {prom:.2f}')

# %% [markdown]
# ### 🏋️ Ejercicio 12 — Funciones
#
# 1. Crea una función `clasificar_nota(nota)` que reciba una nota (0-100) y retorne su clasificación (usa el ejercicio 10 de condicionales como referencia).
# 2. Crea una función `reporte_estudiante(nombre, nota)` que use `clasificar_nota()` internamente y retorne un string con el formato:
#    `"Estudiante: Ana | Nota: 85 | Clasificación: Aprobado"`
# 3. Prueba la función con 3 estudiantes distintos.

# %%
# tu codigo aqui
def clasificar_nota(nota):
    """Clasifica una nota de 0 a 100."""
    if nota >= 90:
        return 'Sobresaliente'
    elif nota >= 70:
        return 'Aprobado'
    elif nota >= 60:
        return 'En riesgo'
    else:
        return 'Reprobado'


def reporte_estudiante(nombre, nota):
    """
    Genera el reporte de un estudiante.
    nombre : str . debe ser el nombre del estudiante
    nota : int . debe ser la nota que recibe el estudiante por su examen
    """
    clasificacion = clasificar_nota(nota)
    return f'Estudiante: {nombre} | Nota: {nota} | Clasificación: {clasificacion}'

print(reporte_estudiante('Ana', 85))
print(reporte_estudiante('Carlos', 55))
print(reporte_estudiante('Juliana', 95))

# %%
print(reporte_estudiante('Ana', 85))

# %% [markdown]
# ---
# ## 13. Lambda y Map
#
# ### Lambda — función anónima
# Una **lambda** es una función de una sola expresión, sin nombre, definida en línea.
#
# ```python
# lambda argumento : expresion
# ```
#
# ### Map — aplicar función a cada elemento
# `map(funcion, iterable)` aplica una función a **cada elemento** de una lista y retorna un objeto map (convertir a `list()` para verlo).

# %%
# funcion lambda basica
duplicar = lambda x: x * 2
print(duplicar(5))    # 10
print(duplicar(7))    # 14
print(duplicar(17))    # 14

# %%
# lambda con dos argumentos
sumar = lambda a, b: a + b
print(sumar(3, 4))    # 7
print(sumar('Hola ','Mundo'))    # 7

# %%
# map con funcion definida
def elevar_cuadrado(x):
    return x ** 2

numeros = [1, 2, 3, 4, 5]
# listar el objeto mapeable luego de aplicar la funcion a cada elemento del iterable
resultado = list(map(elevar_cuadrado, numeros))
print(resultado)   # [1, 4, 9, 16, 25]

# %%
# map con lambda (forma compacta y comun en Data Science)
numeros = [1, 2, 3, 4, 5]
cuadrados = list(map(lambda x: x ** 2, numeros))
print(cuadrados)

# %%
# aplicar a textos
nombres = ['  andres  ', '  MARIA  ', '  juan  ']
nombres_limpios = list(map(lambda n: n.strip().title(), nombres))
print(nombres_limpios)

# %% [markdown]
# ### 🏋️ Ejercicio 13 — Lambda y Map
#
# Tienes una lista de precios en pesos colombianos: `[50000, 120000, 35000, 80000, 200000]`
#
# 1. Usando **`map` + `lambda`**, crea una nueva lista con los precios con el **IVA del 19%** aplicado.
# 2. Usando **`map` + `lambda`**, crea una lista con cada precio formateado como string:
#    `"$50,000"`, `"$120,000"`, etc.
# 3. **Bonus:** Usa `map` + `lambda` para verificar cuáles precios (con IVA) son mayores a `$100.000` — retorna una lista de booleanos.

# %%
# tu codigo aqui
precios = [50000, 120000, 35000, 80000, 200000]
iva = 0.19

# punto 1
precios_con_iva = list(map(lambda p: p*(1+iva), precios))
print('Con IVA:', precios_con_iva)

# punto 2
precios_formato = list(map(lambda p: f'${p:,.0f}', precios))
print('Formato:', precios_formato)

# punto 3 - bonus
mayores_100k = list(map(lambda p: p>100000, precios_con_iva))
print('Mayores a $100.000:', mayores_100k)

# %% [markdown]
# ---
#
# ## 14. Errores y excepciones

# %% [markdown]
# Gestión de Errores y Excepciones
#
#
# Conceptos Fundamentales
# * Errores de Sintaxis (SyntaxError): El código está mal escrito y se detecta antes de ejecutarse. El intérprete ni siquiera arranca. No se pueden capturar.
# * Excepciones de Tiempo de Ejecución (Exception): El código es sintácticamente correcto, pero falla al ejecutarse (ej. dividir entre cero o buscar un archivo inexistente). Se controlan con try/except.

# %% [markdown]
# * error por division por cero

# %%
dividendo = 5
divisor = 0
dividendo / divisor

# %%
dividendo = 5
divisor = 0

try: # intente realizar...
  cociente = dividendo / divisor
  print(cociente)
except: # en caso de no poder realizarlo, haga lo siguiente
  print("No se permite la división por cero")

# %% [markdown]
# * error por fuera de rango

# %%
txt = 'siete' # asigno un texto a una variable

print(txt[7])

# %%
txt = 'siete' # asigno un texto a una variable

try: # intente realizar...
  print(txt[7])
except: # en caso de no poder realizarlo, haga lo siguiente
  print("Ojo : no es por ahí No existe el elemento buscado")

# %% [markdown]
# * ejemplo

# %%
# Lista heterogénea: números en texto, un cero y un valor no numérico
valores = ["10", "0", "5", "abc", "3"]

for v in valores:
    try:
        numero = int(v)           # ⇢ puede lanzar ValueError
        resultado = 1 / numero    # ⇢ puede lanzar ZeroDivisionError
    except ValueError:
        print(f"{v!r} no es un entero válido") # especificador de conversión dentro de las f-strings de Python  (incluye comillas simples)
    except ZeroDivisionError:
        print("No se puede dividir por cero")
    else:
        # Se ejecuta solo si todo lo anterior salió bien
        print(f"Inverso de {numero} = {resultado}")
    finally:
        # Se ejecuta SIEMPRE; perfecto para cerrar recursos o dejar trazas
        print("→ Fin de iteración\n")

# %% [markdown]
# ---
# ## Reto Final Integrador
#
# Usa todo lo aprendido: variables, listas, diccionarios, funciones, bucles y lambdas.
#
# **Contexto:** Tienes un equipo de estudiantes con sus notas en 3 materias. Debes generar un reporte.
#
# El diccionario de entrada es:
# ```python
# equipo = {
#     'Ana':     [85, 92, 78],
#     'Carlos':  [55, 63, 70],
#     'Juliana': [95, 88, 97],
#     'Pedro':   [40, 58, 51]
# }
# ```
#
# **Tareas:**
# 1. Crea una función `promedio(notas)` que calcule el promedio de una lista.
# 2. Recorre el diccionario y para cada estudiante calcula su promedio y clasificación.
# 3. Imprime el reporte con el formato:
#    `"Ana | Promedio: 85.0 | Aprobado"`
# 4. **Bonus:** Usando `map` + `lambda`, obtén la lista de promedios de todos los estudiantes.

# %%
# tu codigo aqui
equipo = {
    'Ana':     [85, 92, 78],
    'Carlos':  [55, 63, 70],
    'Juliana': [95, 88, 97],
    'Pedro':   [40, 58, 51]
}

def promedio(notas):
    """Calcula el promedio de una lista de notas."""
    return 

def clasificar_nota(nota):
    """Clasifica una nota de 0 a 100."""
    if nota >= 90:
        return 'Sobresaliente'
    elif nota >= 70:
        return 'Aprobado'
    elif nota >= 60:
        return 'En riesgo'
    else:
        return 'Reprobado'

print('=== REPORTE DEL EQUIPO ===')
for estudiante, notas in equipo.items():
    prom = promedio(notas)
    clasif = clasificar_nota(prom)
    print(f'{estudiante} | Promedio: {prom:.1f} | {clasif}')

print('\n--- Bonus: lista de promedios ---')
lista_notas = list(equipo.values())
lista_promedios = list(map(lambda n: , lista_notas))
print(lista_promedios)

# %% [markdown]
# ---
#
# ## Bibliografía

# %% [markdown]
# * (2022,Montenegro y Montenegro) Aprendizaje profundo. Diplomado de IA y AP.
# * BeginnersGuide. link :https://wiki.python.org/moin/BeginnersGuide/Programmers
# * Uniwebsidad. link :https://uniwebsidad.com/libros/algoritmos-python
